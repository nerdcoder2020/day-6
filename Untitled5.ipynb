# %%
#This is really Fun to do and I think it's of best thing I ever did
#It's number of Chapters some of Manhwas have in certain popular Manhwas Graph

#PART 1

import matplotlib.pyplot as plt
Views = [112,447,775,358,391,882,11,57,49]
Manhwa_series = range(1,10)
plt.plot(Manhwa_series,Views,label= 'Manhwas(Manga Set)',
#marking & coloring the graph as per personal desire
    color ='b',marker ='o',
         markerfacecolor = 'y',
#line styling in graph
            linestyle = '-',
#setting line width
             linewidth ='1.1')

#1st Task =Labeling these *ings
plt.xlabel('Manhwa Series')
plt.ylabel('No. of Chapters')

plt.legend(loc = 'upper left')
#2nd task = Naming the Graph
plt.title('Manhwas Chapters as per different categeory')
plt.show()

# %%
#This is really Fun to do and I think it's of best thing I ever did
#It's number of Chapters some of Manhwas have in certain popular Manhwas Graph
#PART 2
import matplotlib.pyplot as plt
M_ch= [112,447,147,201,191,112,11,57,49]
Mg_ch=[11,145,187,212,161,29,131,273,153]
N_ch = [5,91,101,116,147,136,140,139,120]
Series = range(1,10)

plt.plot(Series, M_ch, label = 'Manhwa Chapters',marker = 'o', markerfacecolor = 'b')
plt.plot(Series, Mg_ch, label = 'Manga Chapters',marker = 'o', markerfacecolor = 'orange')
plt.plot(Series, N_ch, label = 'Novel Chapters',marker = 'o', markerfacecolor = 'g')

plt.xlabel('Manhwa Series')
plt.ylabel('No. of Chapters')

plt.legend(loc = 'upper left')

#3rd Task Labeling Limits X & Y axis(Just for extra functionality and use)
plt.xlim(1,6)
plt.ylim(100,300)
#2nd task = Naming the Graph
plt.title('Manhwas Chapters as per different categeory')
plt.show()

# %%
#This is really Fun to do and I think it's of best thing I ever did
#It's number of Chapters some of Manhwas have in certain popular Manhwas Graph
#PART 3
import matplotlib.pyplot as plt
M_ch= [112,447,147,201,191,112,11,57,49]
Mg_ch=[11,145,187,212,161,29,131,273,153]
N_ch = [5,91,101,116,147,136,140,139,120]
Series = range(1,10)

plt.plot(Series, M_ch, label = 'Manhwa Chapters',marker = 'o', markerfacecolor = 'b')
plt.plot(Series, Mg_ch, label = 'Manga Chapters',marker = 'o', markerfacecolor = 'orange')
plt.plot(Series, N_ch, label = 'Novel Chapters',marker = 'o', markerfacecolor = 'g')

plt.xlabel('Manhwa Series')
plt.ylabel('No. of Chapters')

plt.legend(loc = 'upper left')

#4th task = Applying gridlines
plt.grid(True, linewidth = 1, color ='r', linestyle ='-.')

#2nd task = Naming the Graph
plt.title('Manhwas Chapters as per different categeory')
plt.show()

# %%
#This is really Fun to do and I think it's of best thing I ever did
#It's number of Chapters some of Manhwas have in certain popular Manhwas Graph

#PART 4,it's new method as Scatter method

import matplotlib.pyplot as plt
Views = [112,447,775,358,391,882,11,57,49]
Manhwa_series = range(1,10)
plt.scatter(Manhwa_series,Views,label= 'Manhwas(Manga Set)')
plt.xlabel('Manhwa Series')
plt.ylabel('No. of Chapters')

plt.legend(loc = 'upper left')
#2nd task = Naming the Graph
plt.title('Manhwas Chapters as per different categeory')
plt.grid(True, linewidth = 1, linestyle ='-.')
plt.show()

# %%
#PART 5,making Bar Charts
#This is really Fun to do and I think it's of best thing I ever did
#It's number of Chapters some of Manhwas have in certain popular Manhwas Graph
#PART 2
import matplotlib.pyplot as plt
M_ch= [112,447,147,201,191,112,11,57,49]
Mg_ch=[11,145,187,212,161,29,131,273,153]
N_ch = [5,91,101,116,147,136,140,139,120]
Series = range(1,10)

plt.bar([a-0.25 for a in Series], M_ch, label = 'Manhwa Chapters')
plt.bar([a-0.5 for a in Series], Mg_ch, label = 'Manga Chapters')
plt.bar([a+0.25 for a in Series], N_ch, label = 'Novel Chapters')

plt.xlabel('Manhwa Series')
plt.ylabel('No. of Chapters')

plt.legend(loc = 'upper left')

#3rd Task Labeling Limits X & Y axis(Just for extra functionality and use)
plt.xlim(1,6)
plt.ylim(100,300)
#2nd task = Naming the Graph
plt.title('Manhwas Chapters as per different categeory')
plt.show()

# %%
#PART 6,making pie chart
import matplotlib.pyplot as plt

labels = ['Manhwa','Manga','Novel']
Chapters = [324,121,61]
explode = [ 0,0,0.1]

plt.pie(views, labels = labels,explode = explode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 8
#       5 Chapters = [324,121,61]
#       6 explode = [ 0,0,0.1]
# ----> 8 plt.pie(views, labels = labels,explode = explode)
#
# NameError: name 'views' is not defined
